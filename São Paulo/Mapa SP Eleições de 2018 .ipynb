# %% [markdown]
# # Mapa SP Eleições de 2018

# %%
#importando
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import geopandas as gpd

# %%
#abrindo o shapefile sp
df_mapa = gpd.read_file('./shapefile_SP/35MUE250GC_SIR.shp')
df_mapa.head()
# Out:
#        NM_MUNICIP CD_GEOCMU                                           geometry
# 0        GUAIÇARA   3517208  POLYGON ((-49.82514 -21.58632, -49.82509 -21.5...
# 1       AURIFLAMA   3504206  POLYGON ((-50.61899 -20.66481, -50.61869 -20.6...
# 2         IPAUSSU   3520905  POLYGON ((-49.67444 -23.05396, -49.67364 -23.0...
# 3     HORTOLÂNDIA   3519071  POLYGON ((-47.24001 -22.84656, -47.24036 -22.8...
# 4  BARRA DO TURVO   3505401  POLYGON ((-48.50267 -24.74675, -48.50245 -24.7...

# %%
df_mapa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 645 entries, 0 to 644
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NM_MUNICIP  645 non-null    object
#  1   CD_GEOCMU   645 non-null    object
#  2   geometry    645 non-null    geometry
# dtypes: geometry(1), object(2)
# memory usage: 15.2+ KB

# %%
#Plotando grafico
df_mapa.plot()
# Out:
# <AxesSubplot:>

# %%
#Aumentando e tirando os eixos do mapa

fig, ax = plt.subplots(1, figsize=(12,12))

# Desenha o mapa
df_mapa.plot(ax=ax)

#Tirando os eixos

ax.set_axis_off()

#plota
plt.show()

# %%
#abrir arquivo de eleicoes 2018 Sp
df_votacao = pd.read_csv('dados_eleicao/votacao_candidato_munzona_2018_SP.csv', sep=';', encoding='latin1')
df_votacao.head().T
# Out:
#                                                        0  \
# DT_GERACAO                                    11/04/2021
# HH_GERACAO                                      09:43:10
# ANO_ELEICAO                                         2018
# CD_TIPO_ELEICAO                                        2
# NM_TIPO_ELEICAO                        Eleição Ordinária
# NR_TURNO                                               1
# CD_ELEICAO                                           297
# DS_ELEICAO                ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                    07/10/2018
# TP_ABRANGENCIA                                         E
# SG_UF                                                 SP
# SG_UE                                                 SP
# NM_UE                                          SÃO PAULO
# CD_MUNICIPIO                                       70750
# NM_MUNICIPIO                       SÃO BERNARDO DO CAMPO
# NR_ZONA                                              283
# CD_CARGO                                               7
# DS_CARGO                               Deputado Estadual
# SQ_CANDIDATO                                250000601493
# NR_CANDIDATO                                       50088
# NM_CANDIDATO                         PAULO PEREIRA ROCHA
# NM_URNA_CANDIDATO                            PAULO ROCHA
# NM_SOCIAL_CANDIDATO                               #NULO#
# CD_SITUACAO_CANDIDATURA                               12
# DS_SITUACAO_CANDIDATURA                             APTO
# CD_DETALHE_SITUACAO_CAND                               2
# DS_DETALHE_SITUACAO_CAND                        DEFERIDO
# TP_AGREMIACAO                                  Coligação
# NR_PARTIDO                                            50
# SG_PARTIDO                                          PSOL
# NM_PARTIDO                Partido Socialismo e Liberdade
# SQ_COLIGACAO                                250000050048
# NM_COLIGACAO                 SEM MEDO DE MUDAR SÃO PAULO
# DS_COMPOSICAO_COLIGACAO                       PSOL / PCB
# CD_SIT_TOT_TURNO                                       5
# DS_SIT_TOT_TURNO                                SUPLENTE
# ST_VOTO_EM_TRANSITO                                    N
# QT_VOTOS_NOMINAIS                                      0
#
#                                                        1  \
# DT_GERACAO                                    11/04/2021
# HH_GERACAO                                      09:43:10
# ANO_ELEICAO                                         2018
# CD_TIPO_ELEICAO                                        2
# NM_TIPO_ELEICAO                        Eleição Ordinária
# NR_TURNO                                               1
# CD_ELEICAO                                           297
# DS_ELEICAO                ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                    07/10/2018
# TP_ABRANGENCIA                                         E
# SG_UF                                                 SP
# SG_UE                                                 SP
# NM_UE                                          SÃO PAULO
# CD_MUNICIPIO                                       62340
# NM_MUNICIPIO                                      NANTES
# NR_ZONA                                              106
# CD_CARGO                                               7
# DS_CARGO                               Deputado Estadual
# SQ_CANDIDATO                                250000602935
# NR_CANDIDATO                                       51478
# NM_CANDIDATO                  MARIA DERLÂNIA LIMA SANTOS
# NM_URNA_CANDIDATO                          DERLÂNIA LIMA
# NM_SOCIAL_CANDIDATO                               #NULO#
# CD_SITUACAO_CANDIDATURA                               12
# DS_SITUACAO_CANDIDATURA                             APTO
# CD_DETALHE_SITUACAO_CAND                               2
# DS_DETALHE_SITUACAO_CAND                        DEFERIDO
# TP_AGREMIACAO                            Partido isolado
# NR_PARTIDO                                            51
# SG_PARTIDO                                         PATRI
# NM_PARTIDO                                      Patriota
# SQ_COLIGACAO                                250000050086
# NM_COLIGACAO                             PARTIDO ISOLADO
# DS_COMPOSICAO_COLIGACAO                            PATRI
# CD_SIT_TOT_TURNO                                       5
# DS_SIT_TOT_TURNO                                SUPLENTE
# ST_VOTO_EM_TRANSITO                                    N
# QT_VOTOS_NOMINAIS                                      0
#
#                                                        2  \
# DT_GERACAO                                    11/04/2021
# HH_GERACAO                                      09:43:10
# ANO_ELEICAO                                         2018
# CD_TIPO_ELEICAO                                        2
# NM_TIPO_ELEICAO                        Eleição Ordinária
# NR_TURNO                                               1
# CD_ELEICAO                                           297
# DS_ELEICAO                ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                    07/10/2018
# TP_ABRANGENCIA                                         E
# SG_UF                                                 SP
# SG_UE                                                 SP
# NM_UE                                          SÃO PAULO
# CD_MUNICIPIO                                       69019
# NM_MUNICIPIO                                     POMPÉIA
# NR_ZONA                                               99
# CD_CARGO                                               7
# DS_CARGO                               Deputado Estadual
# SQ_CANDIDATO                                250000602935
# NR_CANDIDATO                                       51478
# NM_CANDIDATO                  MARIA DERLÂNIA LIMA SANTOS
# NM_URNA_CANDIDATO                          DERLÂNIA LIMA
# NM_SOCIAL_CANDIDATO                               #NULO#
# CD_SITUACAO_CANDIDATURA                               12
# DS_SITUACAO_CANDIDATURA                             APTO
# CD_DETALHE_SITUACAO_CAND                               2
# DS_DETALHE_SITUACAO_CAND                        DEFERIDO
# TP_AGREMIACAO                            Partido isolado
# NR_PARTIDO                                            51
# SG_PARTIDO                                         PATRI
# NM_PARTIDO                                      Patriota
# SQ_COLIGACAO                                250000050086
# NM_COLIGACAO                             PARTIDO ISOLADO
# DS_COMPOSICAO_COLIGACAO                            PATRI
# CD_SIT_TOT_TURNO                                       5
# DS_SIT_TOT_TURNO                                SUPLENTE
# ST_VOTO_EM_TRANSITO                                    N
# QT_VOTOS_NOMINAIS                                      0
#
#                                                         3  \
# DT_GERACAO                                     11/04/2021
# HH_GERACAO                                       09:43:10
# ANO_ELEICAO                                          2018
# CD_TIPO_ELEICAO                                         2
# NM_TIPO_ELEICAO                         Eleição Ordinária
# NR_TURNO                                                1
# CD_ELEICAO                                            297
# DS_ELEICAO                 ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                     07/10/2018
# TP_ABRANGENCIA                                          E
# SG_UF                                                  SP
# SG_UE                                                  SP
# NM_UE                                           SÃO PAULO
# CD_MUNICIPIO                                        69590
# NM_MUNICIPIO                              RIBEIRÃO BONITO
# NR_ZONA                                               107
# CD_CARGO                                                6
# DS_CARGO                                 Deputado Federal
# SQ_CANDIDATO                                 250000623532
# NR_CANDIDATO                                         1240
# NM_CANDIDATO                ANA CLAUDIA FERREIRA DE PAIVA
# NM_URNA_CANDIDATO                               ANA PAIVA
# NM_SOCIAL_CANDIDATO                                #NULO#
# CD_SITUACAO_CANDIDATURA                                12
# DS_SITUACAO_CANDIDATURA                              APTO
# CD_DETALHE_SITUACAO_CAND                                2
# DS_DETALHE_SITUACAO_CAND                         DEFERIDO
# TP_AGREMIACAO                             Partido isolado
# NR_PARTIDO                                             12
# SG_PARTIDO                                            PDT
# NM_PARTIDO                Partido Democrático Trabalhista
# SQ_COLIGACAO                                 250000050629
# NM_COLIGACAO                              PARTIDO ISOLADO
# DS_COMPOSICAO_COLIGACAO                               PDT
# CD_SIT_TOT_TURNO                                        5
# DS_SIT_TOT_TURNO                                 SUPLENTE
# ST_VOTO_EM_TRANSITO                                     N
# QT_VOTOS_NOMINAIS                                       0
#
#                                                         4
# DT_GERACAO                                     11/04/2021
# HH_GERACAO                                       09:43:10
# ANO_ELEICAO                                          2018
# CD_TIPO_ELEICAO                                         2
# NM_TIPO_ELEICAO                         Eleição Ordinária
# NR_TURNO                                                1
# CD_ELEICAO                                            297
# DS_ELEICAO                 ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                     07/10/2018
# TP_ABRANGENCIA                                          E
# SG_UF                                                  SP
# SG_UE                                                  SP
# NM_UE                                           SÃO PAULO
# CD_MUNICIPIO                                        68713
# NM_MUNICIPIO                                      PIQUETE
# NR_ZONA                                                68
# CD_CARGO                                                6
# DS_CARGO                                 Deputado Federal
# SQ_CANDIDATO                                 250000623532
# NR_CANDIDATO                                         1240
# NM_CANDIDATO                ANA CLAUDIA FERREIRA DE PAIVA
# NM_URNA_CANDIDATO                               ANA PAIVA
# NM_SOCIAL_CANDIDATO                                #NULO#
# CD_SITUACAO_CANDIDATURA                                12
# DS_SITUACAO_CANDIDATURA                              APTO
# CD_DETALHE_SITUACAO_CAND                                2
# DS_DETALHE_SITUACAO_CAND                         DEFERIDO
# TP_AGREMIACAO                             Partido isolado
# NR_PARTIDO                                             12
# SG_PARTIDO                                            PDT
# NM_PARTIDO                Partido Democrático Trabalhista
# SQ_COLIGACAO                                 250000050629
# NM_COLIGACAO                              PARTIDO ISOLADO
# DS_COMPOSICAO_COLIGACAO                               PDT
# CD_SIT_TOT_TURNO                                        5
# DS_SIT_TOT_TURNO                                 SUPLENTE
# ST_VOTO_EM_TRANSITO                                     N
# QT_VOTOS_NOMINAIS                                       0

# %%
df_votacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2706938 entries, 0 to 2706937
# Data columns (total 38 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   DT_GERACAO                object
#  1   HH_GERACAO                object
#  2   ANO_ELEICAO               int64
#  3   CD_TIPO_ELEICAO           int64
#  4   NM_TIPO_ELEICAO           object
#  5   NR_TURNO                  int64
#  6   CD_ELEICAO                int64
#  7   DS_ELEICAO                object
#  8   DT_ELEICAO                object
#  9   TP_ABRANGENCIA            object
#  10  SG_UF                     object
#  11  SG_UE                     object
#  12  NM_UE                     object
#  13  CD_MUNICIPIO              int64
#  14  NM_MUNICIPIO              object
#  15  NR_ZONA                   int64
#  16  CD_CARGO                  int64
#  17  DS_CARGO                  object
#  18  SQ_CANDIDATO              int64
#  19  NR_CANDIDATO              int64
#  20  NM_CANDIDATO              object
#  21  NM_URNA_CANDIDATO         object
#  22  NM_SOCIAL_CANDIDATO       object
#  23  CD_SITUACAO_CANDIDATURA   int64
#  24  DS_SITUACAO_CANDIDATURA   object
#  25  CD_DETALHE_SITUACAO_CAND  int64
#  26  DS_DETALHE_SITUACAO_CAND  object
#  27  TP_AGREMIACAO             object
#  28  NR_PARTIDO                int64
#  29  SG_PARTIDO                object
#  30  NM_PARTIDO                object
#  31  SQ_COLIGACAO              int64
#  32  NM_COLIGACAO              object
#  33  DS_COMPOSICAO_COLIGACAO   object
#  34  CD_SIT_TOT_TURNO          int64
#  35  DS_SIT_TOT_TURNO          object
#  36  ST_VOTO_EM_TRANSITO       object
#  37  QT_VOTOS_NOMINAIS         int64
# dtypes: int64(15), object(23)
# memory usage: 784.8+ MB

# %%
# Pegando so as linhas do 2Turno
df_votacao = df_votacao[df_votacao['NR_TURNO'] == 2]

# %%
df_votacao.sample(3).T
# Out:
#                                                           548413   \
# DT_GERACAO                                             11/04/2021
# HH_GERACAO                                               09:43:10
# ANO_ELEICAO                                                  2018
# CD_TIPO_ELEICAO                                                 2
# NM_TIPO_ELEICAO                                 Eleição Ordinária
# NR_TURNO                                                        2
# CD_ELEICAO                                                    298
# DS_ELEICAO                         ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                             28/10/2018
# TP_ABRANGENCIA                                                  E
# SG_UF                                                          SP
# SG_UE                                                          SP
# NM_UE                                                   SÃO PAULO
# CD_MUNICIPIO                                                69655
# NM_MUNICIPIO                                      RIBEIRÃO DO SUL
# NR_ZONA                                                       313
# CD_CARGO                                                        3
# DS_CARGO                                               Governador
# SQ_CANDIDATO                                         250000612596
# NR_CANDIDATO                                                   45
# NM_CANDIDATO                  JOÃO AGRIPINO DA COSTA DORIA JUNIOR
# NM_URNA_CANDIDATO                                      JOÃO DORIA
# NM_SOCIAL_CANDIDATO                                        #NULO#
# CD_SITUACAO_CANDIDATURA                                        12
# DS_SITUACAO_CANDIDATURA                                      APTO
# CD_DETALHE_SITUACAO_CAND                                        2
# DS_DETALHE_SITUACAO_CAND                                 DEFERIDO
# TP_AGREMIACAO                                           Coligação
# NR_PARTIDO                                                     45
# SG_PARTIDO                                                   PSDB
# NM_PARTIDO                Partido da Social Democracia Brasileira
# SQ_COLIGACAO                                         250000050340
# NM_COLIGACAO                                            ACELERASP
# DS_COMPOSICAO_COLIGACAO         PSDB / DEM / PSD / PRB / PP / PTC
# CD_SIT_TOT_TURNO                                                1
# DS_SIT_TOT_TURNO                                           ELEITO
# ST_VOTO_EM_TRANSITO                                             N
# QT_VOTOS_NOMINAIS                                            1092
#
#                                                           1726316  \
# DT_GERACAO                                             11/04/2021
# HH_GERACAO                                               09:43:10
# ANO_ELEICAO                                                  2018
# CD_TIPO_ELEICAO                                                 2
# NM_TIPO_ELEICAO                                 Eleição Ordinária
# NR_TURNO                                                        2
# CD_ELEICAO                                                    298
# DS_ELEICAO                         ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                             28/10/2018
# TP_ABRANGENCIA                                                  E
# SG_UF                                                          SP
# SG_UE                                                          SP
# NM_UE                                                   SÃO PAULO
# CD_MUNICIPIO                                                68357
# NM_MUNICIPIO                                          PEDERNEIRAS
# NR_ZONA                                                        86
# CD_CARGO                                                        3
# DS_CARGO                                               Governador
# SQ_CANDIDATO                                         250000612596
# NR_CANDIDATO                                                   45
# NM_CANDIDATO                  JOÃO AGRIPINO DA COSTA DORIA JUNIOR
# NM_URNA_CANDIDATO                                      JOÃO DORIA
# NM_SOCIAL_CANDIDATO                                        #NULO#
# CD_SITUACAO_CANDIDATURA                                        12
# DS_SITUACAO_CANDIDATURA                                      APTO
# CD_DETALHE_SITUACAO_CAND                                        2
# DS_DETALHE_SITUACAO_CAND                                 DEFERIDO
# TP_AGREMIACAO                                           Coligação
# NR_PARTIDO                                                     45
# SG_PARTIDO                                                   PSDB
# NM_PARTIDO                Partido da Social Democracia Brasileira
# SQ_COLIGACAO                                         250000050340
# NM_COLIGACAO                                            ACELERASP
# DS_COMPOSICAO_COLIGACAO         PSDB / DEM / PSD / PRB / PP / PTC
# CD_SIT_TOT_TURNO                                                1
# DS_SIT_TOT_TURNO                                           ELEITO
# ST_VOTO_EM_TRANSITO                                             N
# QT_VOTOS_NOMINAIS                                           13481
#
#                                                                     879060
# DT_GERACAO                                                       11/04/2021
# HH_GERACAO                                                         09:43:10
# ANO_ELEICAO                                                            2018
# CD_TIPO_ELEICAO                                                           2
# NM_TIPO_ELEICAO                                           Eleição Ordinária
# NR_TURNO                                                                  2
# CD_ELEICAO                                                              298
# DS_ELEICAO                                   ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                                       28/10/2018
# TP_ABRANGENCIA                                                            E
# SG_UF                                                                    SP
# SG_UE                                                                    SP
# NM_UE                                                             SÃO PAULO
# CD_MUNICIPIO                                                          62260
# NM_MUNICIPIO                                                       TAQUARAL
# NR_ZONA                                                                  98
# CD_CARGO                                                                  3
# DS_CARGO                                                         Governador
# SQ_CANDIDATO                                                   250000615141
# NR_CANDIDATO                                                             40
# NM_CANDIDATO                                       MARCIO LUIZ FRANÇA GOMES
# NM_URNA_CANDIDATO                                             MARCIO FRANÇA
# NM_SOCIAL_CANDIDATO                                                  #NULO#
# CD_SITUACAO_CANDIDATURA                                                  12
# DS_SITUACAO_CANDIDATURA                                                APTO
# CD_DETALHE_SITUACAO_CAND                                                  2
# DS_DETALHE_SITUACAO_CAND                                           DEFERIDO
# TP_AGREMIACAO                                                     Coligação
# NR_PARTIDO                                                               40
# SG_PARTIDO                                                              PSB
# NM_PARTIDO                                    Partido Socialista Brasileiro
# SQ_COLIGACAO                                                   250000050400
# NM_COLIGACAO                                      SÃO PAULO CONFIA E AVANÇA
# DS_COMPOSICAO_COLIGACAO   PSB / PSC / PPS / PTB / PV / PR / PODE / PMB /...
# CD_SIT_TOT_TURNO                                                          4
# DS_SIT_TOT_TURNO                                                 NÃO ELEITO
# ST_VOTO_EM_TRANSITO                                                       N
# QT_VOTOS_NOMINAIS                                                       682

# %%
df_votacao['NM_URNA_CANDIDATO'].value_counts()
# Out:
# MARCIO FRANÇA    780
# JOÃO DORIA       780
# Name: NM_URNA_CANDIDATO, dtype: int64

# %%
# Eliminar algumas colunas no df  q n sera utilizada
df_votacao = df_votacao[['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO', 'NM_URNA_CANDIDATO', 'QT_VOTOS_NOMINAIS']]

df_votacao.head()
# Out:
#       SG_UF  CD_MUNICIPIO          NM_MUNICIPIO  NR_CANDIDATO  \
# 1336     SP         61859                  AVAÍ            40
# 1339     SP         67490       NAZARÉ PAULISTA            40
# 1699     SP         70939  SÃO JOSÉ DO BARREIRO            40
# 12954    SP         66079                   JAÚ            45
# 12955    SP         64734               GUARIBA            45
#
#       NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS
# 1336      MARCIO FRANÇA               1550
# 1339      MARCIO FRANÇA               3333
# 1699      MARCIO FRANÇA               1452
# 12954        JOÃO DORIA              47417
# 12955        JOÃO DORIA               9130

# %%
# os dados estao separados por municipio/zona
#Municipios peq normalmente tem apenas 1 zona eleitoral
# mas municipios maiores podem ter varias zonas eleitorais

# vms verificar SÃO PAULO
df_votacao[df_votacao['NM_MUNICIPIO'] == 'SÃO PAULO']
# Out:
#         SG_UF  CD_MUNICIPIO NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 12956      SP         71072    SÃO PAULO            45        JOÃO DORIA
# 51999      SP         71072    SÃO PAULO            45        JOÃO DORIA
# 57170      SP         71072    SÃO PAULO            45        JOÃO DORIA
# 68766      SP         71072    SÃO PAULO            40     MARCIO FRANÇA
# 105668     SP         71072    SÃO PAULO            40     MARCIO FRANÇA
# ...       ...           ...          ...           ...               ...
# 2556989    SP         71072    SÃO PAULO            45        JOÃO DORIA
# 2618119    SP         71072    SÃO PAULO            45        JOÃO DORIA
# 2635444    SP         71072    SÃO PAULO            40     MARCIO FRANÇA
# 2638510    SP         71072    SÃO PAULO            45        JOÃO DORIA
# 2675228    SP         71072    SÃO PAULO            45        JOÃO DORIA
#
#          QT_VOTOS_NOMINAIS
# 12956                31186
# 51999                31768
# 57170                45092
# 68766                51499
# 105668               45872
# ...                    ...
# 2556989              37737
# 2618119              88052
# 2635444              54677
# 2638510              29900
# 2675228              26566
#
# [116 rows x 6 columns]

# %%
# Precisamos agregar os dados por municipio e candidato
df_votacao.groupby(['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO', 'NM_URNA_CANDIDATO']).sum()
# Out:
#                                                                               QT_VOTOS_NOMINAIS
# SG_UF CD_MUNICIPIO NM_MUNICIPIO               NR_CANDIDATO NM_URNA_CANDIDATO
# SP    61000        EUCLIDES DA CUNHA PAULISTA 40           MARCIO FRANÇA                   2874
#                                               45           JOÃO DORIA                      1285
#       61018        ADAMANTINA                 40           MARCIO FRANÇA                   7392
#                                               45           JOÃO DORIA                      9948
#       61026        BOREBI                     40           MARCIO FRANÇA                    656
# ...                                                                                         ...
#       72435        VOTORANTIM                 45           JOÃO DORIA                     37260
#       72451        VOTUPORANGA                40           MARCIO FRANÇA                  18131
#                                               45           JOÃO DORIA                     26056
#       72737        VARGEM GRANDE PAULISTA     40           MARCIO FRANÇA                  11495
#                                               45           JOÃO DORIA                     13113
#
# [1290 rows x 1 columns]

# %%
# Fazer o groupby, reindexar o indice vai salvar em um df
df_votacao = df_votacao.groupby(['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO', 'NM_URNA_CANDIDATO']).sum().reset_index()
df_votacao.sample(4)
# Out:
#      SG_UF  CD_MUNICIPIO            NM_MUNICIPIO  NR_CANDIDATO  \
# 846     SP         68039       PALMARES PAULISTA            40
# 1126    SP         70831   SÃO JOÃO DA BOA VISTA            40
# 1170    SP         71277  SEBASTIANÓPOLIS DO SUL            40
# 59      SP         61298             ALVINLÂNDIA            45
#
#      NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS
# 846      MARCIO FRANÇA               1879
# 1126     MARCIO FRANÇA              15085
# 1170     MARCIO FRANÇA                887
# 59          JOÃO DORIA                768

# %%
df_votacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1290 entries, 0 to 1289
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SG_UF              1290 non-null   object
#  1   CD_MUNICIPIO       1290 non-null   int64
#  2   NM_MUNICIPIO       1290 non-null   object
#  3   NR_CANDIDATO       1290 non-null   int64
#  4   NM_URNA_CANDIDATO  1290 non-null   object
#  5   QT_VOTOS_NOMINAIS  1290 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 60.6+ KB

# %%
# vms verificar SÃO PAULO
df_votacao[df_votacao['NM_MUNICIPIO'] == 'SÃO PAULO']
# Out:
#      SG_UF  CD_MUNICIPIO NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 1150    SP         71072    SÃO PAULO            40     MARCIO FRANÇA
# 1151    SP         71072    SÃO PAULO            45        JOÃO DORIA
#
#       QT_VOTOS_NOMINAIS
# 1150            3393092
# 1151            2447309

# %%
# ordena o df pela qtd de vts e dps dx apenas o primeiro
# Resgistro de cada municipio
df_votacao.sort_values(by='QT_VOTOS_NOMINAIS',  ascending=False, inplace=True)

# %%
df_votacao.head(10)
# Out:
#      SG_UF  CD_MUNICIPIO           NM_MUNICIPIO  NR_CANDIDATO  \
# 1150    SP         71072              SÃO PAULO            40
# 1151    SP         71072              SÃO PAULO            45
# 520     SP         64777              GUARULHOS            40
# 335     SP         62910               CAMPINAS            45
# 521     SP         64777              GUARULHOS            45
# 1143    SP         70998    SÃO JOSÉ DOS CAMPOS            45
# 334     SP         62910               CAMPINAS            40
# 1118    SP         70750  SÃO BERNARDO DO CAMPO            40
# 1189    SP         71455               SOROCABA            45
# 1101    SP         70572            SANTO ANDRÉ            45
#
#      NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS
# 1150     MARCIO FRANÇA            3393092
# 1151        JOÃO DORIA            2447309
# 520      MARCIO FRANÇA             322148
# 335         JOÃO DORIA             315524
# 521         JOÃO DORIA             240825
# 1143        JOÃO DORIA             232775
# 334      MARCIO FRANÇA             230899
# 1118     MARCIO FRANÇA             208941
# 1189        JOÃO DORIA             207470
# 1101        JOÃO DORIA             202125

# %%
#dropa as linhas duplicadas, mantendo a primeira

df_votacao.drop_duplicates(subset='CD_MUNICIPIO', keep='first', inplace=True)
df_votacao.head(10)
# Out:
#      SG_UF  CD_MUNICIPIO           NM_MUNICIPIO  NR_CANDIDATO  \
# 1150    SP         71072              SÃO PAULO            40
# 520     SP         64777              GUARULHOS            40
# 335     SP         62910               CAMPINAS            45
# 1143    SP         70998    SÃO JOSÉ DOS CAMPOS            45
# 1118    SP         70750  SÃO BERNARDO DO CAMPO            40
# 1189    SP         71455               SOROCABA            45
# 1101    SP         70572            SANTO ANDRÉ            45
# 832     SP         67890                 OSASCO            40
# 1013    SP         69698         RIBEIRÃO PRETO            45
# 663     SP         66192                JUNDIAÍ            45
#
#      NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS
# 1150     MARCIO FRANÇA            3393092
# 520      MARCIO FRANÇA             322148
# 335         JOÃO DORIA             315524
# 1143        JOÃO DORIA             232775
# 1118     MARCIO FRANÇA             208941
# 1189        JOÃO DORIA             207470
# 1101        JOÃO DORIA             202125
# 832      MARCIO FRANÇA             189320
# 1013        JOÃO DORIA             166728
# 663         JOÃO DORIA             143028

# %%
# vms verificar SÃO PAULO
df_votacao[df_votacao['NM_MUNICIPIO'] == 'SÃO PAULO']
# Out:
#      SG_UF  CD_MUNICIPIO NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 1150    SP         71072    SÃO PAULO            40     MARCIO FRANÇA
#
#       QT_VOTOS_NOMINAIS
# 1150            3393092

# %%
# vamos criar uma coluna representando o resultado da eleiçao naquele municipio
# sendo que o resultado e True se o candidato WILSON WITZEL venceu naquele municipio
# e False em caso contrario
df_votacao['RESULTADO'] = df_votacao['NR_CANDIDATO'].apply(lambda x: x == 40)

# %%
# Verificar o resultado
df_votacao.head()
# Out:
#      SG_UF  CD_MUNICIPIO           NM_MUNICIPIO  NR_CANDIDATO  \
# 1150    SP         71072              SÃO PAULO            40
# 520     SP         64777              GUARULHOS            40
# 335     SP         62910               CAMPINAS            45
# 1143    SP         70998    SÃO JOSÉ DOS CAMPOS            45
# 1118    SP         70750  SÃO BERNARDO DO CAMPO            40
#
#      NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS  RESULTADO
# 1150     MARCIO FRANÇA            3393092       True
# 520      MARCIO FRANÇA             322148       True
# 335         JOÃO DORIA             315524      False
# 1143        JOÃO DORIA             232775      False
# 1118     MARCIO FRANÇA             208941       True

# %%
# recuperar a tabela de correspondencia entre ibge e tse
#Direto do github do Estadão
link = 'https://raw.githubusercontent.com/estadao/como-votou-sua-vizinhanca/master/data/votos/correspondencia-tse-ibge.csv'
df_equivalencia = pd.read_csv(link)
df_equivalencia.head()
# Out:
#              chave          NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# 0    ac acrelandia    ACRELÂNDIA  AC      1200013     1120    NaN
# 1  ac assis brasil  ASSIS BRASIL  AC      1200054     1570    NaN
# 2     ac brasileia     BRASILÉIA  AC      1200104     1058    NaN
# 3        ac bujari        BUJARI  AC      1200138     1007    NaN
# 4      ac capixaba      CAPIXABA  AC      1200179     1015    NaN

# %%
df_equivalencia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   chave        5570 non-null   object
#  1   NOME         5570 non-null   object
#  2   UF           5570 non-null   object
#  3   GEOCOD_IBGE  5570 non-null   int64
#  4   COD_TSE      5570 non-null   int64
#  5   AJUSTE       29 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 261.2+ KB

# %%
df_equivalencia = df_equivalencia[df_equivalencia['UF'] == 'SP']

# %%
df_equivalencia.head()
# Out:
#                     chave              NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# 4786        sp adamantina        ADAMANTINA  SP      3500105    61018    NaN
# 4787            sp adolfo            ADOLFO  SP      3500204    61034    NaN
# 4788             sp aguai             AGUAÍ  SP      3500303    61050    NaN
# 4789    sp aguas da prata    ÁGUAS DA PRATA  SP      3500402    61077    NaN
# 4790  sp aguas de lindoia  ÁGUAS DE LINDÓIA  SP      3500501    61093    NaN

# %%
df_equivalencia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 645 entries, 4786 to 5430
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   chave        645 non-null    object
#  1   NOME         645 non-null    object
#  2   UF           645 non-null    object
#  3   GEOCOD_IBGE  645 non-null    int64
#  4   COD_TSE      645 non-null    int64
#  5   AJUSTE       1 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 35.3+ KB

# %%
#Vamos preparar os dataframes
# vms reindexar o df de votaçao pelo codigo do TSE
df_vot_novo = df_votacao.copy()

df_vot_novo.set_index('CD_MUNICIPIO', drop=False, inplace=True)

df_vot_novo.head()
# Out:
#              SG_UF  CD_MUNICIPIO           NM_MUNICIPIO  NR_CANDIDATO  \
# CD_MUNICIPIO
# 71072           SP         71072              SÃO PAULO            40
# 64777           SP         64777              GUARULHOS            40
# 62910           SP         62910               CAMPINAS            45
# 70998           SP         70998    SÃO JOSÉ DOS CAMPOS            45
# 70750           SP         70750  SÃO BERNARDO DO CAMPO            40
#
#              NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS  RESULTADO
# CD_MUNICIPIO
# 71072            MARCIO FRANÇA            3393092       True
# 64777            MARCIO FRANÇA             322148       True
# 62910               JOÃO DORIA             315524      False
# 70998               JOÃO DORIA             232775      False
# 70750            MARCIO FRANÇA             208941       True

# %%
# vms reindexar o df de Equivalencia pelo o codigo do TSE
df_equi_novo = df_equivalencia.copy()

df_equi_novo.set_index('COD_TSE', drop=False, inplace=True)

df_equi_novo.head()
# Out:
#                        chave              NOME  UF  GEOCOD_IBGE  COD_TSE  \
# COD_TSE
# 61018          sp adamantina        ADAMANTINA  SP      3500105    61018
# 61034              sp adolfo            ADOLFO  SP      3500204    61034
# 61050               sp aguai             AGUAÍ  SP      3500303    61050
# 61077      sp aguas da prata    ÁGUAS DA PRATA  SP      3500402    61077
# 61093    sp aguas de lindoia  ÁGUAS DE LINDÓIA  SP      3500501    61093
#
#         AJUSTE
# COD_TSE
# 61018      NaN
# 61034      NaN
# 61050      NaN
# 61077      NaN
# 61093      NaN

# %%
# Criando um novo dataframe com base no merge de votaçao e Equivalencia

df_vot_equi = df_vot_novo.join(df_equi_novo)

df_vot_equi.head()
# Out:
#              SG_UF  CD_MUNICIPIO           NM_MUNICIPIO  NR_CANDIDATO  \
# CD_MUNICIPIO
# 71072           SP         71072              SÃO PAULO            40
# 64777           SP         64777              GUARULHOS            40
# 62910           SP         62910               CAMPINAS            45
# 70998           SP         70998    SÃO JOSÉ DOS CAMPOS            45
# 70750           SP         70750  SÃO BERNARDO DO CAMPO            40
#
#              NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS  RESULTADO  \
# CD_MUNICIPIO
# 71072            MARCIO FRANÇA            3393092       True
# 64777            MARCIO FRANÇA             322148       True
# 62910               JOÃO DORIA             315524      False
# 70998               JOÃO DORIA             232775      False
# 70750            MARCIO FRANÇA             208941       True
#
#                                  chave                   NOME  UF  \
# CD_MUNICIPIO
# 71072                     sp sao paulo              SÃO PAULO  SP
# 64777                     sp guarulhos              GUARULHOS  SP
# 62910                      sp campinas               CAMPINAS  SP
# 70998           sp sao jose dos campos    SÃO JOSÉ DOS CAMPOS  SP
# 70750         sp sao bernardo do campo  SÃO BERNARDO DO CAMPO  SP
#
#               GEOCOD_IBGE  COD_TSE AJUSTE
# CD_MUNICIPIO
# 71072             3550308    71072    NaN
# 64777             3518800    64777    NaN
# 62910             3509502    62910    NaN
# 70998             3549904    70998    NaN
# 70750             3548708    70750    NaN

# %%
df_vot_equi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 645 entries, 71072 to 62430
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SG_UF              645 non-null    object
#  1   CD_MUNICIPIO       645 non-null    int64
#  2   NM_MUNICIPIO       645 non-null    object
#  3   NR_CANDIDATO       645 non-null    int64
#  4   NM_URNA_CANDIDATO  645 non-null    object
#  5   QT_VOTOS_NOMINAIS  645 non-null    int64
#  6   RESULTADO          645 non-null    bool
#  7   chave              645 non-null    object
#  8   NOME               645 non-null    object
#  9   UF                 645 non-null    object
#  10  GEOCOD_IBGE        645 non-null    int64
#  11  COD_TSE            645 non-null    int64
#  12  AJUSTE             1 non-null      object
# dtypes: bool(1), int64(5), object(7)
# memory usage: 86.1+ KB

# %%
# Transforma a coluna de codigo de IBGE do df votaçao/equivalencia em str
df_vot_equi['GEOCOD_IBGE'] = df_vot_equi['GEOCOD_IBGE'].astype(str)

df_vot_equi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 645 entries, 71072 to 62430
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SG_UF              645 non-null    object
#  1   CD_MUNICIPIO       645 non-null    int64
#  2   NM_MUNICIPIO       645 non-null    object
#  3   NR_CANDIDATO       645 non-null    int64
#  4   NM_URNA_CANDIDATO  645 non-null    object
#  5   QT_VOTOS_NOMINAIS  645 non-null    int64
#  6   RESULTADO          645 non-null    bool
#  7   chave              645 non-null    object
#  8   NOME               645 non-null    object
#  9   UF                 645 non-null    object
#  10  GEOCOD_IBGE        645 non-null    object
#  11  COD_TSE            645 non-null    int64
#  12  AJUSTE             1 non-null      object
# dtypes: bool(1), int64(4), object(8)
# memory usage: 86.1+ KB

# %%
df_mapa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 645 entries, 0 to 644
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NM_MUNICIP  645 non-null    object
#  1   CD_GEOCMU   645 non-null    object
#  2   geometry    645 non-null    geometry
# dtypes: geometry(1), object(2)
# memory usage: 15.2+ KB

# %%
# vms unificar os indices

# Mudando indice do df mapa
df_mapa.set_index('CD_GEOCMU', drop=False, inplace=True)

df_mapa.head(2)
# Out:
#           NM_MUNICIP CD_GEOCMU  \
# CD_GEOCMU
# 3517208     GUAIÇARA   3517208
# 3504206    AURIFLAMA   3504206
#
#                                                     geometry
# CD_GEOCMU
# 3517208    POLYGON ((-49.82514 -21.58632, -49.82509 -21.5...
# 3504206    POLYGON ((-50.61899 -20.66481, -50.61869 -20.6...

# %%
# muda o indice do df votaçao/equivalencia
df_vot_equi.set_index('GEOCOD_IBGE', drop=False, inplace=True)
df_vot_equi.head(2)
# Out:
#             SG_UF  CD_MUNICIPIO NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# GEOCOD_IBGE
# 3550308        SP         71072    SÃO PAULO            40     MARCIO FRANÇA
# 3518800        SP         64777    GUARULHOS            40     MARCIO FRANÇA
#
#              QT_VOTOS_NOMINAIS  RESULTADO         chave       NOME  UF  \
# GEOCOD_IBGE
# 3550308                3393092       True  sp sao paulo  SÃO PAULO  SP
# 3518800                 322148       True  sp guarulhos  GUARULHOS  SP
#
#             GEOCOD_IBGE  COD_TSE AJUSTE
# GEOCOD_IBGE
# 3550308         3550308    71072    NaN
# 3518800         3518800    64777    NaN

# %%
# vms unificar o dataframe do mapa com dataframe de votaçao/equivalencia
df_mapa_novo = df_mapa.join(df_vot_equi)

df_mapa_novo.head().T
# Out:
# CD_GEOCMU                                                    3517208  \
# NM_MUNICIP                                                  GUAIÇARA
# CD_GEOCMU                                                    3517208
# geometry           POLYGON ((-49.82513799999998 -21.5863189989999...
# SG_UF                                                             SP
# CD_MUNICIPIO                                                   64459
# NM_MUNICIPIO                                                GUAIÇARA
# NR_CANDIDATO                                                      45
# NM_URNA_CANDIDATO                                         JOÃO DORIA
# QT_VOTOS_NOMINAIS                                               2945
# RESULTADO                                                      False
# chave                                                    sp guaicara
# NOME                                                        GUAIÇARA
# UF                                                                SP
# GEOCOD_IBGE                                                  3517208
# COD_TSE                                                        64459
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    3504206  \
# NM_MUNICIP                                                 AURIFLAMA
# CD_GEOCMU                                                    3504206
# geometry           POLYGON ((-50.61899032899998 -20.6648102479999...
# SG_UF                                                             SP
# CD_MUNICIPIO                                                   61832
# NM_MUNICIPIO                                               AURIFLAMA
# NR_CANDIDATO                                                      45
# NM_URNA_CANDIDATO                                         JOÃO DORIA
# QT_VOTOS_NOMINAIS                                               4376
# RESULTADO                                                      False
# chave                                                   sp auriflama
# NOME                                                       AURIFLAMA
# UF                                                                SP
# GEOCOD_IBGE                                                  3504206
# COD_TSE                                                        61832
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    3520905  \
# NM_MUNICIP                                                   IPAUSSU
# CD_GEOCMU                                                    3520905
# geometry           POLYGON ((-49.67443545799995 -23.0539566549999...
# SG_UF                                                             SP
# CD_MUNICIPIO                                                   65196
# NM_MUNICIPIO                                                 IPAUSSU
# NR_CANDIDATO                                                      40
# NM_URNA_CANDIDATO                                      MARCIO FRANÇA
# QT_VOTOS_NOMINAIS                                               3841
# RESULTADO                                                       True
# chave                                                     sp ipaussu
# NOME                                                         IPAUSSU
# UF                                                                SP
# GEOCOD_IBGE                                                  3520905
# COD_TSE                                                        65196
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    3519071  \
# NM_MUNICIP                                               HORTOLÂNDIA
# CD_GEOCMU                                                    3519071
# geometry           POLYGON ((-47.24001299999998 -22.8465629989999...
# SG_UF                                                             SP
# CD_MUNICIPIO                                                   61727
# NM_MUNICIPIO                                             HORTOLÂNDIA
# NR_CANDIDATO                                                      45
# NM_URNA_CANDIDATO                                         JOÃO DORIA
# QT_VOTOS_NOMINAIS                                              51601
# RESULTADO                                                      False
# chave                                                 sp hortolandia
# NOME                                                     HORTOLÂNDIA
# UF                                                                SP
# GEOCOD_IBGE                                                  3519071
# COD_TSE                                                        61727
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    3505401
# NM_MUNICIP                                            BARRA DO TURVO
# CD_GEOCMU                                                    3505401
# geometry           POLYGON ((-48.50267192599995 -24.7467511309999...
# SG_UF                                                             SP
# CD_MUNICIPIO                                                   62073
# NM_MUNICIPIO                                          BARRA DO TURVO
# NR_CANDIDATO                                                      40
# NM_URNA_CANDIDATO                                      MARCIO FRANÇA
# QT_VOTOS_NOMINAIS                                               2132
# RESULTADO                                                       True
# chave                                              sp barra do turvo
# NOME                                                  BARRA DO TURVO
# UF                                                                SP
# GEOCOD_IBGE                                                  3505401
# COD_TSE                                                        62073
# AJUSTE                                                           NaN

# %%
# verificando o tam do mapa novo
df_mapa_novo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 645 entries, 3517208 to 3535507
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NM_MUNICIP         645 non-null    object
#  1   CD_GEOCMU          645 non-null    object
#  2   geometry           645 non-null    geometry
#  3   SG_UF              645 non-null    object
#  4   CD_MUNICIPIO       645 non-null    int64
#  5   NM_MUNICIPIO       645 non-null    object
#  6   NR_CANDIDATO       645 non-null    int64
#  7   NM_URNA_CANDIDATO  645 non-null    object
#  8   QT_VOTOS_NOMINAIS  645 non-null    int64
#  9   RESULTADO          645 non-null    bool
#  10  chave              645 non-null    object
#  11  NOME               645 non-null    object
#  12  UF                 645 non-null    object
#  13  GEOCOD_IBGE        645 non-null    object
#  14  COD_TSE            645 non-null    int64
#  15  AJUSTE             1 non-null      object
# dtypes: bool(1), geometry(1), int64(4), object(10)
# memory usage: 101.3+ KB

# %%
#Matar a coluna ajuste
df_mapa_novo.drop(columns=['AJUSTE'], inplace=True)

# %%
# vamos desenhar o mapa

#Criar a referencia para o codigo de cor(False/0 = yellow True/1 = green)
from matplotlib.colors import ListedColormap

cmap = ListedColormap(['blue', 'orange'])

#Desenhar o mapa
fig, ax = plt.subplots(1, figsize=(12, 12))

ax = df_mapa_novo.plot(column='NM_URNA_CANDIDATO', cmap=cmap, legend=True, linewidth=0.1, ax=ax, edgecolor='grey')

# Esconder os eixos
ax.set_axis_off()

#Colocando titulo
ax.set_title('Resultado Eleiçao 2018 por Municipio / 2 Turno SP', fontdict={'fontsize': '25', 'fontweight': '3'})

#Criando uma nota rodape
ax.annotate('Fonte: IBGE, TSE, 2019; Jornal o Estado de São Paulo, 2019',
    xy=(0.1, 0.08), xycoords='figure fraction', horizontalalignment='left',
    verticalalignment='top', fontsize=10, color='#555555')

#Exibir

plt.show()
